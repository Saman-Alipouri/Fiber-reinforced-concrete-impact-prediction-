# %%
# !pip install pandas numpy scikit-learn xgboost matplotlib seaborn

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-676e4277-5064-4dfc-bed0-4b4cebd5178e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-676e4277-5064-4dfc-bed0-4b4cebd5178e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# بارگذاری داده
df = pd.read_csv("impact_resistance.csv")
df.head()
# Out:
#    CuringTemp SampleName    FC    UR  PINPB    FCU     URU
# 0         -10    Control  2.00  2.33   0.17  40.70   47.49
# 1         -10        PO1  3.67  8.33   1.31  74.62  169.59
# 2         -10   PO1+SR10  3.33  6.33   0.92  67.84  128.89
# 3         -10       SR10  3.00  4.33   0.44  61.05   88.19
# 4          25    Control  1.00  1.67   0.67  20.35   33.92

# %%
df.describe()
# Out:
#        CuringTemp        FC        UR     PINPB        FCU         URU
# count    8.000000  8.000000  8.000000  8.000000   8.000000    8.000000
# mean     7.500000  2.291250  4.582500  1.001250  46.636250   93.276250
# std     18.708287  0.950796  2.485356  0.725228  19.337689   50.601687
# min    -10.000000  1.000000  1.670000  0.170000  20.350000   33.920000
# 25%    -10.000000  1.832500  2.247500  0.612500  37.307500   45.792500
# 50%      7.500000  2.000000  4.500000  0.795000  40.700000   91.580000
# 75%     25.000000  3.082500  6.497500  1.315000  62.747500  132.282500
# max     25.000000  3.670000  8.330000  2.500000  74.620000  169.590000

# %%
sns.pairplot(df, hue='SampleName')
plt.suptitle("Pairplot by Mix Type", y=1.02)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df[['FCU', 'URU']])
plt.title("Boxplot of Impact Energies")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.multioutput import MultiOutputRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from xgboost import XGBRegressor
import numpy as np

# Features and targets
X = df.drop(columns=["SampleName", "FCU", "URU"])
y = df[["FCU", "URU"]]

# Split data
X_train, X_test, y_train, y_test = train_test_split(
X, y, test_size=0.25, random_state=42
)

# Model
model = MultiOutputRegressor(XGBRegressor(random_state=42))
model.fit(X_train, y_train)

# Predict
y_pred = model.predict(X_test)

# Evaluation
print(" Evaluation on Test Set:")
for i in range(y.shape[1]):
    actual = y_test.iloc[:, i]
    predicted = y_pred[:, i]
    print(f"\n--- {y.columns[i]} ---")
    print(f"R² Score: {r2_score(actual, predicted):.4f}")
    print(f"MAE : {mean_absolute_error(actual, predicted):.4f}")
    print(f"RMSE : {np.sqrt(mean_squared_error(actual, predicted)):.4f}")
# Out:
#  Evaluation on Test Set:
#
# --- FCU ---
# R² Score: 0.9201
# MAE : 3.3906
# RMSE : 4.7950
#
# --- URU ---
# R² Score: -9.6296
# MAE : 44.0957
# RMSE : 44.2261

# %%
plt.figure(figsize=(12,5))

for i, col in enumerate(["FCU", "URU"]):
    plt.subplot(1, 2, i+1)
    plt.scatter(y_test[col], y_pred[:, i], color='blue')
    plt.plot([y_test[col].min(), y_test[col].max()],
    [y_test[col].min(), y_test[col].max()], 'r--')
    plt.xlabel("Actual")
    plt.ylabel("Predicted")
    plt.title(f"{col} Prediction")
    plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# نمایش اهمیت ویژگی‌ها برای هر خروجی
for i, col in enumerate(y.columns):
    plt.figure()
    model.estimators_[i].feature_importances_ # برای هر خروجی
    plt.bar(X.columns, model.estimators_[i].feature_importances_)
    plt.title(f"Feature Importance for {col}")
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
import pickle
with open("impact_model.pkl", "wb") as f:
    pickle.dump(model, f)

# %%
from google.colab import files
files.download("impact_model.pkl")
